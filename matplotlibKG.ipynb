# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
veri=pd.read_csv("nba.csv")
veri
# Out:
#        Unnamed: 0         player_name team_abbreviation   age  player_height  \
# 0               0       Dennis Rodman               CHI  36.0         198.12
# 1               1   Dwayne Schintzius               LAC  28.0         215.90
# 2               2        Earl Cureton               TOR  39.0         205.74
# 3               3         Ed O'Bannon               DAL  24.0         203.20
# 4               4         Ed Pinckney               MIA  34.0         205.74
# ...           ...                 ...               ...   ...            ...
# 11140       11140         Maxi Kleber               DAL  28.0         208.28
# 11141       11141  Melvin Frazier Jr.               ORL  23.0         195.58
# 11142       11142      Meyers Leonard               MIA  28.0         213.36
# 11143       11143        Norvel Pelle               PHI  27.0         208.28
# 11144       11144         Matt Thomas               TOR  25.0         193.04
#
# ...

# %%
pts=veri[veri["player_name"]=="Kevin Garnett"]["pts"]
pts
# Out:
# 337     17.0
# 543     18.5
# 1094    20.8
# 1698    22.9
# 2084    22.0
# 2254    21.2
# 3007    23.0
# 3134    24.2
# 3578    22.2
# 4032    21.8
# 4817    22.4
# 5163    18.8
# 5412    15.8
# 6164    14.3
# 6246    14.9
# 7025    15.8
# 7458    14.8
# 7973     6.5
# 8339     6.9
# 8793     3.2
# Name: pts, dtype: float64

# %%
season=veri[veri["player_name"]=="Kevin Garnett"]["season"]
season
# Out:
# 337     1996-97
# 543     1997-98
# 1094    1998-99
# 1698    1999-00
# 2084    2000-01
# 2254    2001-02
# 3007    2002-03
# 3134    2003-04
# 3578    2004-05
# 4032    2005-06
# 4817    2006-07
# 5163    2007-08
# 5412    2008-09
# 6164    2009-10
# 6246    2010-11
# 7025    2011-12
# 7458    2012-13
# 7973    2013-14
# 8339    2014-15
# 8793    2015-16
# Name: season, dtype: object

# %%
grafik=plt.figure(figsize=(25,6))

eksen=grafik.add_axes([0.1,0.1,0.7,0.7])
eksen.plot(season,pts,color="red")
