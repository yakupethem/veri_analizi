# %%
import pandas as pd

# %%
data=pd.read_csv("nba.csv")
data
# Out:
#        Unnamed: 0         player_name team_abbreviation   age  player_height  \
# 0               0       Dennis Rodman               CHI  36.0         198.12
# 1               1   Dwayne Schintzius               LAC  28.0         215.90
# 2               2        Earl Cureton               TOR  39.0         205.74
# 3               3         Ed O'Bannon               DAL  24.0         203.20
# 4               4         Ed Pinckney               MIA  34.0         205.74
# ...           ...                 ...               ...   ...            ...
# 11140       11140         Maxi Kleber               DAL  28.0         208.28
# 11141       11141  Melvin Frazier Jr.               ORL  23.0         195.58
# 11142       11142      Meyers Leonard               MIA  28.0         213.36
# 11143       11143        Norvel Pelle               PHI  27.0         208.28
# 11144       11144         Matt Thomas               TOR  25.0         193.04
#
# ...

# %%
data.groupby("team_abbreviation").get_group("MIN")[["player_name","pts"]].sort_values(by="pts",ascending=False)
# Out:
#               player_name   pts
# 11069  Karl-Anthony Towns  26.5
# 7974           Kevin Love  26.1
# 7026           Kevin Love  26.0
# 9186   Karl-Anthony Towns  25.1
# 10549  Karl-Anthony Towns  24.4
# ...                   ...   ...
# 9293       John Lucas III   0.4
# 7193          Will Conroy   0.3
# 5762          Mark Madsen   0.3
# 990         Trevor Winter   0.0
# 8467         Ronny Turiaf   0.0
#
# [366 rows x 2 columns]

# %%
data["player_name"].unique()
# Out:
# array(['Dennis Rodman', 'Dwayne Schintzius', 'Earl Cureton', ...,
#        'Max Strus', 'Norvel Pelle', 'Matt Thomas'], dtype=object)

# %%
data.groupby("team_abbreviation").get_group("MIN")["player_name"].value_counts()
# Out:
# Kevin Garnett        13
# Anthony Peeler        6
# Gorgui Dieng          6
# Sam Mitchell          6
# Wally Szczerbiak      6
#                      ..
# Will Conroy           1
# AJ Price              1
# DeJuan Wheat          1
# Jordan McLaughlin     1
# Allen Crabbe          1
# Name: player_name, Length: 188, dtype: int64

# %%
data.head(10)
# Out:
#    Unnamed: 0        player_name team_abbreviation   age  player_height  \
# 0           0      Dennis Rodman               CHI  36.0         198.12
# 1           1  Dwayne Schintzius               LAC  28.0         215.90
# 2           2       Earl Cureton               TOR  39.0         205.74
# 3           3        Ed O'Bannon               DAL  24.0         203.20
# 4           4        Ed Pinckney               MIA  34.0         205.74
# 5           5      Eddie Johnson               HOU  38.0         200.66
# 6           6        Eddie Jones               LAL  25.0         198.12
# 7           7     Elden Campbell               LAL  28.0         213.36
# 8           8  Eldridge Recasner               ATL  29.0         193.04
# 9           9       Elliot Perry               MIL  28.0         182.88
#
#    player_weight                      college country draft_year draft_round  \
# 0      99.790240  Southeastern Oklahoma State     USA       1986           2
# ...

# %%
data["age"].mean()
# Out:
# 27.168685509196948

# %%
data["age"].max()
# Out:
# 44.0

# %%
data[data["age"]==data["age"].max()]["player_name"]
# Out:
# 4820    Kevin Willis
# Name: player_name, dtype: object

# %%
data[data["player_name"]=="Kevin Garnett"].sort_values(ascending=False,by="pts")
# Out:
#       Unnamed: 0    player_name team_abbreviation   age  player_height  \
# 3134        3134  Kevin Garnett               MIN  28.0         210.82
# 3007        3007  Kevin Garnett               MIN  27.0         210.82
# 1698        1698  Kevin Garnett               MIN  24.0         210.82
# 4817        4817  Kevin Garnett               MIN  31.0         210.82
# 3578        3578  Kevin Garnett               MIN  29.0         210.82
# 2084        2084  Kevin Garnett               MIN  25.0         210.82
# 4032        4032  Kevin Garnett               MIN  30.0         210.82
# 2254        2254  Kevin Garnett               MIN  26.0         210.82
# 1094        1094  Kevin Garnett               MIN  23.0         210.82
# 5163        5163  Kevin Garnett               BOS  32.0         210.82
# 543          543  Kevin Garnett               MIN  22.0         210.82
# 337          337  Kevin Garnett               MIN  21.0         210.82
# ...

# %%
data[(data["age"]>=20)&(data["age"]<25)][["player_name","team_abbreviation","age"]].sort_values(by="age",ascending=False)
# Out:
#                     player_name team_abbreviation   age
# 3                   Ed O'Bannon               DAL  24.0
# 8058                 Jan Vesely               DEN  24.0
# 3797                 Brian Cook               LAL  24.0
# 3793           Curtis Borchardt               UTA  24.0
# 3791                  DJ Mbenga               DAL  24.0
# ...                         ...               ...   ...
# 10731                 Ja Morant               MEM  20.0
# 4440             Ersan Ilyasova               MIL  20.0
# 3986   Martynas Andriuskevicius               CLE  20.0
# 3985            Marvin Williams               ATL  20.0
# 5794           Anthony Randolph               GSW  20.0
#
# [3531 rows x 3 columns]

# %%
data[data["player_name"]=="Kevin Garnett"][["team_abbreviation","season"]]
# Out:
#      team_abbreviation   season
# 337                MIN  1996-97
# 543                MIN  1997-98
# 1094               MIN  1998-99
# 1698               MIN  1999-00
# 2084               MIN  2000-01
# 2254               MIN  2001-02
# 3007               MIN  2002-03
# 3134               MIN  2003-04
# 3578               MIN  2004-05
# 4032               MIN  2005-06
# 4817               MIN  2006-07
# 5163               BOS  2007-08
# 5412               BOS  2008-09
# 6164               BOS  2009-10
# 6246               BOS  2010-11
# 7025               BOS  2011-12
# 7458               BOS  2012-13
# 7973               BKN  2013-14
# 8339               MIN  2014-15
# 8793               MIN  2015-16

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'player_name', 'team_abbreviation', 'age',
#        'player_height', 'player_weight', 'college', 'country', 'draft_year',
#        'draft_round', 'draft_number', 'gp', 'pts', 'reb', 'ast', 'net_rating',
#        'oreb_pct', 'dreb_pct', 'usg_pct', 'ts_pct', 'ast_pct', 'season'],
#       dtype='object')

# %%
data.groupby("team_abbreviation")["age"].mean()
# Out:
# team_abbreviation
# ATL    26.903394
# BKN    26.700000
# BOS    26.651226
# CHA    26.299213
# CHH    29.056180
# CHI    26.810298
# CLE    26.953846
# DAL    28.250000
# DEN    26.569892
# DET    27.497207
# GSW    26.789894
# HOU    27.984127
# IND    27.126685
# LAC    27.341902
# LAL    27.309973
# MEM    26.403175
# MIA    28.410853
# MIL    27.204852
# MIN    26.904372
# NJN    27.455253
# NOH    27.356643
# NOK    26.625000
# NOP    26.581967
# NYK    27.832884
# OKC    26.133333
# ORL    27.024457
# PHI    26.457895
# PHX    27.071823
# POR    26.539510
# SAC    26.784916
# SAS    29.103448
# SEA    27.395604
# TOR    27.033333
# UTA    27.008333
# VAN    27.138889
# WAS    26.910290
# Name: age, dtype: float64

# %%
data.groupby("team_abbreviation").count()
# Out:
#                    Unnamed: 0  player_name  age  player_height  player_weight  \
# team_abbreviation
# ATL                       383          383  383            383            383
# BKN                       140          140  140            140            140
# BOS                       367          367  367            367            367
# CHA                       254          254  254            254            254
# CHH                        89           89   89             89             89
# CHI                       369          369  369            369            369
# CLE                       390          390  390            390            390
# DAL                       384          384  384            384            384
# DEN                       372          372  372            372            372
# DET                       358          358  358            358            358
# GSW                       376          376  376            376            376
# ...

# %%
data.groupby("team_abbreviation")["player_name"].count()
# Out:
# team_abbreviation
# ATL    383
# BKN    140
# BOS    367
# CHA    254
# CHH     89
# CHI    369
# CLE    390
# DAL    384
# DEN    372
# DET    358
# GSW    376
# HOU    378
# IND    371
# LAC    389
# LAL    371
# MEM    315
# MIA    387
# MIL    371
# MIN    366
# NJN    257
# NOH    143
# NOK     32
# NOP    122
# NYK    371
# OKC    195
# ORL    368
# PHI    380
# PHX    362
# POR    367
# SAC    358
# SAS    377
# SEA    182
# TOR    390
# UTA    360
# VAN     72
# WAS    379
# Name: player_name, dtype: int64

# %%
data["team_abbreviation"].nunique()
# Out:
# 36

# %%
data["team_abbreviation"].value_counts(ascending=False)
# Out:
# CLE    390
# TOR    390
# LAC    389
# MIA    387
# DAL    384
# ATL    383
# PHI    380
# WAS    379
# HOU    378
# SAS    377
# GSW    376
# DEN    372
# LAL    371
# NYK    371
# IND    371
# MIL    371
# CHI    369
# ORL    368
# BOS    367
# POR    367
# MIN    366
# PHX    362
# UTA    360
# SAC    358
# DET    358
# MEM    315
# NJN    257
# CHA    254
# OKC    195
# SEA    182
# NOH    143
# BKN    140
# NOP    122
# CHH     89
# VAN     72
# NOK     32
# Name: team_abbreviation, dtype: int64

# %%
data[data["player_name"].str.contains("LeBron")]
# Out:
#        Unnamed: 0   player_name team_abbreviation   age  player_height  \
# 3120         3120  LeBron James               CLE  19.0         203.20
# 3617         3617  LeBron James               CLE  20.0         203.20
# 4075         4075  LeBron James               CLE  21.0         203.20
# 4778         4778  LeBron James               CLE  22.0         203.20
# 5104         5104  LeBron James               CLE  23.0         203.20
# 5430         5430  LeBron James               CLE  24.0         203.20
# 6127         6127  LeBron James               CLE  25.0         203.20
# 6266         6266  LeBron James               MIA  26.0         203.20
# 7004         7004  LeBron James               MIA  27.0         203.20
# 7428         7428  LeBron James               MIA  28.0         203.20
# 7954         7954  LeBron James               MIA  29.0         203.20
# 8322         8322  LeBron James               CLE  30.0         203.20
# ...
