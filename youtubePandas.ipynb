# %%
import pandas as pd

# %%
veri=pd.read_csv("GBvideos.csv")

# %%
veri
# Out:
#           video_id trending_date  \
# 0      Jw1Y-zhQURU      17.14.11
# 1      3s1rvMFUweQ      17.14.11
# 2      n1WpP7iowLc      17.14.11
# 3      PUTEiSjKwJU      17.14.11
# 4      rHwDegptbI4      17.14.11
# ...            ...           ...
# 38911  l884wKofd54      18.14.06
# 38912  IP8k2xkhOdI      18.14.06
# 38913  Il-an3K9pjg      18.14.06
# 38914  -DRsfNObKIQ      18.14.06
# 38915  4YFo4bdMO8Q      18.14.06
#
#                                                    title  \
# 0          John Lewis Christmas Ad 2017 - #MozTheMonster
# 1              Taylor Swift: …Ready for It? (Live) - SNL
# 2             Eminem - Walk On Water (Audio) ft. Beyoncé
# 3      Goals from Salford City vs Class of 92 and Fri...
# 4      Dashcam captures truck's near miss with child ...
# ...                                                  ...
# 38911  Enrique Iglesias - MOVE TO MIAMI (Official Vid...
# 38912  Jacob Sartorius - Up With It (Official Music V...
# ...

# %%
veri.head(10)
# Out:
#       video_id trending_date  \
# 0  Jw1Y-zhQURU      17.14.11
# 1  3s1rvMFUweQ      17.14.11
# 2  n1WpP7iowLc      17.14.11
# 3  PUTEiSjKwJU      17.14.11
# 4  rHwDegptbI4      17.14.11
# 5  AumaWl0TNBo      17.14.11
# 6  2Vv-BfVoq4g      17.14.11
# 7  -N5eucPMTTc      17.14.11
# 8  LMCuKltaY3M      17.14.11
# 9  9t9u_yPEidY      17.14.11
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# 4  Dashcam captures truck's near miss with child ...
# 5                       How My Relationship Started!
# 6        Ed Sheeran - Perfect (Official Music Video)
# 7                      CHRISTMAS HAS GONE TO MY HEAD
# 8   Elbow - Golden Slumbers (John Lewis Advert 2017)
# 9  Jennifer Lopez - Amor, Amor, Amor (Official Vi...
#
# ...

# %%
veri[5:10]
# Out:
#       video_id trending_date  \
# 5  AumaWl0TNBo      17.14.11
# 6  2Vv-BfVoq4g      17.14.11
# 7  -N5eucPMTTc      17.14.11
# 8  LMCuKltaY3M      17.14.11
# 9  9t9u_yPEidY      17.14.11
#
#                                                title       channel_title  \
# 5                       How My Relationship Started!  PointlessBlogVlogs
# 6        Ed Sheeran - Perfect (Official Music Video)          Ed Sheeran
# 7                      CHRISTMAS HAS GONE TO MY HEAD          MoreZoella
# 8   Elbow - Golden Slumbers (John Lewis Advert 2017)           ElbowVEVO
# 9  Jennifer Lopez - Amor, Amor, Amor (Official Vi...   JenniferLopezVEVO
#
#    category_id              publish_time  \
# 5           24  2017-11-11T17:00:00.000Z
# 6           10  2017-11-09T11:04:14.000Z
# 7           22  2017-11-10T19:19:43.000Z
# 8           10  2017-11-10T08:00:01.000Z
# 9           10  2017-11-10T15:00:00.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
veri.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
veri.columns.value_counts()
# Out:
# description               1
# comment_count             1
# publish_time              1
# video_error_or_removed    1
# video_id                  1
# dislikes                  1
# channel_title             1
# views                     1
# title                     1
# ratings_disabled          1
# tags                      1
# trending_date             1
# category_id               1
# likes                     1
# comments_disabled         1
# thumbnail_link            1
# dtype: int64

# %%
len(veri.columns)
# Out:
# 16

# %%
veri.drop(['comment_count','thumbnail_link', 'comments_disabled', 'ratings_disabled','video_error_or_removed', 'description'],axis=1)
# Out:
#           video_id trending_date  \
# 0      Jw1Y-zhQURU      17.14.11
# 1      3s1rvMFUweQ      17.14.11
# 2      n1WpP7iowLc      17.14.11
# 3      PUTEiSjKwJU      17.14.11
# 4      rHwDegptbI4      17.14.11
# ...            ...           ...
# 38911  l884wKofd54      18.14.06
# 38912  IP8k2xkhOdI      18.14.06
# 38913  Il-an3K9pjg      18.14.06
# 38914  -DRsfNObKIQ      18.14.06
# 38915  4YFo4bdMO8Q      18.14.06
#
#                                                    title  \
# 0          John Lewis Christmas Ad 2017 - #MozTheMonster
# 1              Taylor Swift: …Ready for It? (Live) - SNL
# 2             Eminem - Walk On Water (Audio) ft. Beyoncé
# 3      Goals from Salford City vs Class of 92 and Fri...
# 4      Dashcam captures truck's near miss with child ...
# ...                                                  ...
# 38911  Enrique Iglesias - MOVE TO MIAMI (Official Vid...
# 38912  Jacob Sartorius - Up With It (Official Music V...
# ...

# %%
veri[["likes","dislikes"]].mean()
# Out:
# likes       134519.553500
# dislikes      7612.559975
# dtype: float64

# %%
veri[["likes","dislikes"]].head(50)
# Out:
#       likes  dislikes
# 0     55681     10247
# 1     25561      2294
# 2    787420     43420
# 3       193        12
# 4        30         2
# 5     52708      1431
# 6   1634124     21082
# 7     57309       749
# 8      2163       147
# 9    190084     15015
# 10     9591       266
# 11     1746       125
# 12    37986       816
# 13     8133      2693
# 14    98804     11682
# 15    12553      2146
# 16    22326       833
# 17   286269      4083
# 18   202676      3394
# 19    72593      1830
# 20    10028       248
# 21   263918      1502
# 22   207262      3167
# 23    25115       499
# 24     4577       292
# 25    52829      1524
# 26      629        77
# 27     5029        81
# 28   307435      2573
# 29      399        14
# 30     5364       153
# 31     7999        84
# 32    84426      1130
# 33     1881       182
# 34      240        16
# 35   126078     10294
# 36       33         6
# 37     1267        38
# 38     4604        46
# 39    53572       168
# ...

# %%
veri
# Out:
#           video_id trending_date  \
# 0      Jw1Y-zhQURU      17.14.11
# 1      3s1rvMFUweQ      17.14.11
# 2      n1WpP7iowLc      17.14.11
# 3      PUTEiSjKwJU      17.14.11
# 4      rHwDegptbI4      17.14.11
# ...            ...           ...
# 38911  l884wKofd54      18.14.06
# 38912  IP8k2xkhOdI      18.14.06
# 38913  Il-an3K9pjg      18.14.06
# 38914  -DRsfNObKIQ      18.14.06
# 38915  4YFo4bdMO8Q      18.14.06
#
#                                                    title  \
# 0          John Lewis Christmas Ad 2017 - #MozTheMonster
# 1              Taylor Swift: …Ready for It? (Live) - SNL
# 2             Eminem - Walk On Water (Audio) ft. Beyoncé
# 3      Goals from Salford City vs Class of 92 and Fri...
# 4      Dashcam captures truck's near miss with child ...
# ...                                                  ...
# 38911  Enrique Iglesias - MOVE TO MIAMI (Official Vid...
# 38912  Jacob Sartorius - Up With It (Official Music V...
# ...

# %%
veri[veri["views"]==veri["views"].max()][["title","views"]]
# Out:
#                                                    title      views
# 28412  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  424538912

# %%
veri[veri["views"]==veri["views"].min()][["title","views"]]
# Out:
#                                                   title  views
# 3477  Mountain Bikers Worried About Military Land Be...    851

# %%
veri.sort_values("views",ascending=False).head(10)[["title","views"]]
# Out:
#                                                    title      views
# 28412  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  424538912
# 28212  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  413586699
# 28008  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  402650804
# 27811  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  392036878
# 27615  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  382401497
# 27424  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  372399338
# 27241  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  362111555
# 27052  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  349987176
# 26861  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  339629489
# 34460  Te Bote Remix - Casper, Nio García, Darell, Ni...  337621571

# %%
veri.groupby("category_id").mean().sort_values("likes",ascending=False)["likes"]
# Out:
# category_id
# 10    272138.508943
# 29    271695.733333
# 24     81572.362012
# 23     78431.168490
# 28     61531.127413
# 1      57205.523089
# 22     46273.495899
# 43     41836.900000
# 17     39270.313057
# 20     39220.127517
# 27     38440.687090
# 15     28629.913858
# 26     26639.183091
# 25     25021.685714
# 2      24608.506944
# 19      9674.447917
# Name: likes, dtype: float64

# %%
veri.groupby("category_id").sum().sort_values("comment_count",ascending=False)
# Out:
#                     views       likes   dislikes  comment_count  \
# category_id
# 10           171160864769  3742993052  159370236      293013140
# 24            29786283041   744266231   88106151      116897440
# 22             5754287829   135396249   12002570       18713149
# 23             3962062143   143372176    4630521       16718816
# 1              8362707626   147418633    6192934       15590011
# 17             3341736194    74888487    9914555       10056226
# 25             1409131375    30651565    3780349        9386604
# 29              352798262    24452616    5436854        7672790
# 26             1190155227    51360345    1607193        7356296
# 20             1746619532    70125588    2304458        6166994
# 28             1641388256    31873124    1623049        4029065
# 27              444290557    17567394     593153        1636903
# 15              541320573    15288374     366060        1404698
# ...

# %%
veri["category_id"].value_counts()
# Out:
# 10    13754
# 24     9124
# 22     2926
# 1      2577
# 26     1928
# 17     1907
# 23     1828
# 20     1788
# 25     1225
# 15      534
# 28      518
# 27      457
# 2       144
# 19       96
# 29       90
# 43       20
# Name: category_id, dtype: int64

# %%
veri["adUzunluğu"]=veri["title"].apply(len)
veri
# Out:
#           video_id trending_date  \
# 0      Jw1Y-zhQURU      17.14.11
# 1      3s1rvMFUweQ      17.14.11
# 2      n1WpP7iowLc      17.14.11
# 3      PUTEiSjKwJU      17.14.11
# 4      rHwDegptbI4      17.14.11
# ...            ...           ...
# 38911  l884wKofd54      18.14.06
# 38912  IP8k2xkhOdI      18.14.06
# 38913  Il-an3K9pjg      18.14.06
# 38914  -DRsfNObKIQ      18.14.06
# 38915  4YFo4bdMO8Q      18.14.06
#
#                                                    title  \
# 0          John Lewis Christmas Ad 2017 - #MozTheMonster
# 1              Taylor Swift: …Ready for It? (Live) - SNL
# 2             Eminem - Walk On Water (Audio) ft. Beyoncé
# 3      Goals from Salford City vs Class of 92 and Fri...
# 4      Dashcam captures truck's near miss with child ...
# ...                                                  ...
# 38911  Enrique Iglesias - MOVE TO MIAMI (Official Vid...
# 38912  Jacob Sartorius - Up With It (Official Music V...
# ...

# %%
veri["tagSayısı"]=veri["tags"].apply(lambda x : len(x.split("|")))
veri
# Out:
#           video_id trending_date  \
# 0      Jw1Y-zhQURU      17.14.11
# 1      3s1rvMFUweQ      17.14.11
# 2      n1WpP7iowLc      17.14.11
# 3      PUTEiSjKwJU      17.14.11
# 4      rHwDegptbI4      17.14.11
# ...            ...           ...
# 38911  l884wKofd54      18.14.06
# 38912  IP8k2xkhOdI      18.14.06
# 38913  Il-an3K9pjg      18.14.06
# 38914  -DRsfNObKIQ      18.14.06
# 38915  4YFo4bdMO8Q      18.14.06
#
#                                                    title  \
# 0          John Lewis Christmas Ad 2017 - #MozTheMonster
# 1              Taylor Swift: …Ready for It? (Live) - SNL
# 2             Eminem - Walk On Water (Audio) ft. Beyoncé
# 3      Goals from Salford City vs Class of 92 and Fri...
# 4      Dashcam captures truck's near miss with child ...
# ...                                                  ...
# 38911  Enrique Iglesias - MOVE TO MIAMI (Official Vid...
# 38912  Jacob Sartorius - Up With It (Official Music V...
# ...

# %%
def oran(dataset):
    like=list(veri["likes"])
    dislike=list(veri["dislikes"])
    oranlistesi=[]
    
    liste=list(zip(like,dislike))
    for like,dislike in liste:
        if (like+dislike)==0:
            oranlistesi.append(0)
        else:
            oranlistesi.append(like/(like+dislike))
    return oranlistesi

# %%
veri["begeniOranı"]=oran(veri)

# %%
veri.sort_values("begeniOranı",ascending=False)[["title","likes","dislikes","begeniOranı"]]
# Out:
#                                                    title  likes  dislikes  \
# 36631         Kris Wu – Like That (Official Music Video)  57544         0
# 7088      HIGHLIGHTS: MK Dons U18s 1-0 Cardiff City U18s     30         0
# 5361         QUIZ : Name the Trail : A Christmas Cracker      2         0
# 12082    Lima Sopoaga Tribute🔥🔥||The Unsung Hero||💯 2017     50         0
# 5338   Bohemian Rhapsody (2018) - Scene Bohemian Rhap...     71         0
# ...                                                  ...    ...       ...
# 21547                                    To Our Daughter      0         0
# 22661                      【公式】「劇場版ポケットモンスター みんなの物語」予告編1      0         0
# 24920                    映画『BLEACH』特報【HD】2018年7月20日（金）公開      0         0
# 14864                             Altwork 1 Minute Video      0         0
# 4465                      The New Snapchat in 60 Seconds      0         0
#
#        begeniOranı
# 36631          1.0
# 7088           1.0
# ...
